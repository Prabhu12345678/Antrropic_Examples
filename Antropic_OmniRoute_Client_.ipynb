# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhu12345678/Antrropic_Examples/blob/main/Antropic_OmniRoute_Client_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /usr/local/lib/python3.13/dist-packages (1.5.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (1.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from anthropic) (4.14.2)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.13/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from anthropic) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from anthropic) (2.13.5)
# Requirement already satisfied: sniffio<2,>=1 in /usr/local/lib/python3.13/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.13/dist-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2.0.0->anthropic) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)

# %%
from google.colab import userdata

# Get your API key from Colab secrets
#ANTHROPIC_API_KEY = userdata.get('claude_key')
ANTHROPIC_AUTH_TOKEN = userdata.get('auth_token')

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

# Tunnelling commands worked fine on OS Ubuntu 26.04.01 running on Lenevo T520 Laptop
# Command installs local tunnelling dependencies : @machine> sudo npm install -g localtunnel
# Command exposes local Omniroute llm Collabrator site http://localhost:20128 : @machine> lt --port 20128
# This is a tunneled URL, as OmniRoute is running on local.
# Antropic Python Client code runs on Colab Server hence tunnelling is required
# to exporse local address of the OmniRoute Site

client = Anthropic(
    api_key=ANTHROPIC_AUTH_TOKEN,
    base_url='https://empty-roses-shout.loca.lt',
    timeout=60.0)
model = 'prabhu-stack'

#"ANTHROPIC_BASE_URL": "http://localhost:20128",
#"ANTHROPIC_AUTH_TOKEN": "sk-162a84b111e19fab-95545e-00eb1ff5",
#"ANTHROPIC_API_KEY": "",
#"ANTHROPIC_MODEL": "prabhu-stack",

# %%
def add_user_message(messages, text):
  message = {"role":"user", "content":text}
  messages.append(message)

def add_assitant_message(messages, text):
  message = {"role":"assistant", "content":text}
  messages.append(message)

def chat(messages):
  message = client.messages.create(
      model=model,
      max_tokens=1000,
      messages=messages
      )
  return message.content[0].text

# %%
system_prompt = """
You were a patient math tutoe,
guide students to solve math problems step by step,
rather solving the problems in one go
"""

def chat(messages):
  message = client.messages.create(
      model=model,
      max_tokens=1000,
      messages=messages,
      system=system_prompt
      )
  return message.content[0].text

messages = []

math_prob = "How do I solve 5x + 3 = 2 for x?"

add_user_message(messages, math_prob)

math_sol = chat(messages)

print("\n ", math_sol)
# Out:
#   Hello! I would be absolutely happy to help you solve this.
#
# When we want to solve for $x$, our main goal is to get $x$ all by itself on one side of the equals sign.
#
# Let's look at your equation:
# **5x + 3 = 2**
#
# Right now, $x$ is being multiplied by 5, and then 3 is being added to it. To get $x$ alone, we need to undo these operations one at a time, usually in reverse order.
#
# Let's start with that **+ 3**. What do you think we could do to *both sides* of the equation to cancel out a plus 3? Take a guess!

# %%
def chat(messages, system=None):

  params = {
      "model" : model,
      "max_tokens" : 1000,
      "messages" : messages,
      "system" : system
  }

  if system:
    params['system'] = system


  message = client.messages.create(**params)
  return message.content[0].text

messages = []

system = """
You were a patient math tutor,
guide students to solve math problems step by step,
rather solving the problems in one go
"""

math_prob = "How do I solve 5x + 3 = 2 for x?"

add_user_message(messages, math_prob)

math_sol = chat(messages, system = system)

print("\n ", math_sol)
# Out:
#   Hello there! I would be completely happy to help you solve this equation.
#
# Our main goal when solving for $x$ is to isolate it, meaning we want to get $x$ completely by itself on one side of the equals sign.
#
# Our equation is:
# **$5x + 3 = 2$**
#
# To start getting $x$ by itself, we first need to isolate the term that contains $x$, which is the **$5x$**.
#
# Looking at the equation, we have a "$+ 3$" on the same side as the $5x$. What do you think we should do to both sides of the equation to cancel out that "$+ 3$"?

# %%
import builtins; input = builtins.input

messages = []

while True:
  user_input = input("> ")
  add_user_message(messages, user_input)
  chat_response = chat(messages)
  add_assitant_message(messages, chat_response)
  print("\n---")
  print(chat_response)
  print("\n---")
# Out:
# > Help me plan my trip to Bangalore for a day
#
# ---
# Bangalore (Bengaluru) is a vibrant city, blending a rich history with a booming tech culture, famously known as the Garden City and the Pub Capital of India. Since you only have one day, the key is to group your activities geographically to avoid getting stuck in the city's notorious traffic.
#
# Here is a highly optimized, proactive itinerary for a fantastic one-day trip to Bangalore:
#
# ### 🌞 Morning: Nature and Classic South Indian Breakfast
# *   **8:00 AM – Breakfast at MTR (Mavalli Tiffin Room) or Vidyarthi Bhavan:** Start your day with an authentic South Indian breakfast. If you are near Basavanagudi, go to Vidyarthi Bhavan for their famous crispy Masala Dosa. If you are near Lalbagh, visit MTR for their Rava Idli and filter coffee.
# *   **9:15 AM – Lalbagh Botanical Garden:** Just a short distance from breakfast, take a peaceful morning stroll through this historic 240-acre garden. Don't miss the Glass House and the ancient Lalbagh Rock (one of the oldest rock formations on earth).
#
# ### 🏛️ Mid-Day: Heritage and Architecture
# *   **11:30 AM – Vidhana Soudha & Cubbon Park:** Take the Namma Metro (or an auto) towards the city center. Walk through Cubbon Park, the "lung space" of the city. As you exit, you will see the Vidhana Soudha, the magnificent state legislature building. (Note: You can only view it from the outside, but it makes for great photography).
# *   **12:30 PM – Bangalore Palace:** Head to the Bangalore Palace, inspired by England's Windsor Castle. The wooden interiors, extensive grounds, and royal history are well worth the audio tour.
#
# ### 🍛 Afternoon: Lunch and Exploring
# *   **2:00 PM – Lunch in Central Bangalore:** Head to the Lavelle Road or UB City area. If you want a traditional banana leaf meal, try *Nagarjuna* for incredible Andhra-style biryani and meals. For upscale global cuisine, *UB City* has plenty of great options.
# *   **3:30 PM – Museum or Shopping:**
#     *   *Option A (Art & History):* Visit the National Gallery of Modern Art (NGMA) for a quiet, culturally rich afternoon.
#     *   *Option B (Shopping & Vibe):* Stroll down Commercial Street or Brigade Road for some street shopping, souvenirs, and soaking in the bustling local vibe.
#
# ### 🍻 Evening: The Pub Capital Experience
# *   **6:30 PM – Indiranagar or Koramangala:** Bangalore is highly famous for its microbreweries. Head to Indiranagar (100 Feet Road). It’s packed with trendy cafes, boutiques, and pubs.
# *   **7:30 PM – Dinner and Craft Beer:** Grab a table at one of the iconic breweries like *Toit*, *Windmills Craftworks*, or *Arbor Brewing Company*. Even if you don't drink beer, the food, ambiance, and mocktails at these venues are spectacular.
#
# ### 💡 Pro-Tips for Surviving Bangalore in a Day:
# 1.  **Beat the Traffic:** Traffic can be a major bottleneck. Use the **Namma Metro** whenever possible. For last-mile connectivity, use apps like **Uber, Ola, or Rapido** to book auto-rickshaws. Never negotiate with autos off the street unless you know the local rates.
# 2.  **Weather:** Bangalore has beautiful, moderate weather year-round, but it can rain unexpectedly. Carry an umbrella and a light jacket for the evening.
# 3.  **Airport Logistics:** Keep in mind that the Kempegowda International Airport (BLR) is about 35-40 km away from the city center. Factor in at least 1.5 to 2 hours of travel time if you are flying in or out on the same day. Consider using the *Vayu Vajra* (Kia) Airport AC buses if you want a budget-friendly and comfortable transit.
#
# If you have specific preferences (e.g., you prefer tech/startups, historical temples, or purely food), let me know and I can recompile this itinerary to suit your exact parameters!
#
# ---
# > Keep iternery specific to South Bangalore only, and food to authentic Karnataka delicacies only
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# /tmp/ipykernel_1037/750112483.py in <cell line: 0>()
#       6   user_input = input("> ")
#       7   add_user_message(messages, user_input)
# ----> 8   chat_response = chat(messages)
#       9   add_assitant_message(messages, chat_response)
#      10   print("\n---")
#
# /tmp/ipykernel_1037/2741171081.py in chat(messages, system)
#      12
#      13
# ---> 14   message = client.messages.create(**params)
#      15   return message.content[0].text
#      16
#
# /usr/local/lib/python3.13/dist-packages/anthropic/_utils/_utils.py in wrapper(*args, **kwargs)
#     292                         msg = f"Missing required argument: {quote(missing[0])}"
#     293                 raise TypeError(msg)
# --> 294             return func(*args, **kwargs)
#     295
#     296         return wrapper  # type: ignore
#
# /usr/local/lib/python3.13/dist-packages/anthropic/resources/messages/messages.py in create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     976             **(extra_headers or {}),
#     977         }
# --> 978         return self._post(
#     979             "/v1/messages",
#     980             body=maybe_transform(
#
# /usr/local/lib/python3.13/dist-packages/anthropic/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1507             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1508         )
# -> 1509         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1510
#    1511     def patch(
#
# /usr/local/lib/python3.13/dist-packages/anthropic/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1191                 response.read()
#    1192
# -> 1193             raise self._make_status_error_from_response(response) from None
#    1194
#    1195         raise RuntimeError("could not resolve response (should never happen)")
#
# InternalServerError: Bad Gateway

# %%
def chat(messages, system=None):

  params = {
      "model" : model,
      "max_tokens" : 1000,
      "messages" : messages
  }

  if system:
    params['system'] = system


  message = client.messages.create(**params)
  return message.content[0].text

messages = []

# Note : Precise vs concise
system = "You are a Python Developer writes very concise code."
#system = "You are a Python Developer writes very precise code."

math_prob = "Write a code to remove duplicate letters in a string."

add_user_message(messages, math_prob)

math_sol = chat(messages, system = system)

print("\n ", math_sol)
# Out:
#   # Remove Duplicate Letters
#
# ```python
# def remove_duplicates(s):
#     return "".join(dict.fromkeys(s))
#
# # Example usage
# print(remove_duplicates("programming"))  # "progamin"
# print(remove_duplicates("hello world"))  # "helo wrd"
# print(remove_duplicates("aabbcc"))       # "abc"
# ```
#
# **How it works:** `dict.fromkeys(s)` creates a dictionary with each character as a key (preserving first occurrence order), then we join the keys back into a string. Since dictionary keys are unique, duplicates are automatically removed.

# %%
messages = []

add_user_message(messages, "You were a world food expert, tell me in two sentence, why Indian food is so fascinating?")

assistant_answer = chat(messages)

add_assitant_message(messages, assistant_answer)

print("\n " ,messages)

add_user_message(messages, "Write one more sentence")

assistant_answer = chat(messages)

add_assitant_message(messages, assistant_answer)

print("\n ",messages)
